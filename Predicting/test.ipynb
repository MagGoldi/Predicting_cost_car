# %%
import pandas as pd

# %%
data_car = pd.read_csv('C:\PYTHON\Predicting_cost_car\car_data.csv')    
data_car
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\фвьшт\AppData\Local\Temp\ipykernel_10968\2370474391.py:1: SyntaxWarning: invalid escape sequence '\P'
#   data_car = pd.read_csv('C:\PYTHON\Predicting_cost_car\car_data.csv')
#         Цена Марка   Модель  Год выпуска  \
# 0    1940000   BMW       X5         2011
# 1   11600000   BMW       X6         2021
# 2    2960000   BMW  5 серия         2016
# 3    2049000   BMW       X6         2009
# 4    1494000   BMW       X1         2013
# ..       ...   ...      ...          ...
# 74    605000   BMW  1 серия         2008
# 75   3499000   BMW  5 серия         2018
# 76   4800000   BMW       X3         2020
# 77   9910000   BMW       X5         2021
# 78  14680000   BMW       X5         2023
#
#                                  Поколение      Пробег Владельцев по ПТС  \
# 0               E70 рестайлинг (2010—2013)   184500 км                 3
# ...

# %%
data_car.shape
# Out:
# (79, 19)

# %%
data_car.isnull().sum()
# Out:
# Цена                  0
# Марка                 0
# Модель                0
# Год выпуска           0
# Поколение             0
# Пробег                0
# Владельцев по ПТС     0
# Состояние             0
# Модификация           0
# Объём двигателя       4
# Тип двигателя         0
# Коробка передач       0
# Привод                0
# Комплектация         16
# Тип кузова            0
# Цвет                  0
# Руль                  0
# Обмен                31
# Ссылка                0
# dtype: int64
